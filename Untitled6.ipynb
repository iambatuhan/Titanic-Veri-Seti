# %%
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x="pclass",y="sex",data=df);

# %%
df1=df.pivot_table("survived",["sex","pclass","who","alone"],"embark_town")

# %%
df1
# Out:
# embark_town                Cherbourg  Queenstown  Southampton
# sex    pclass who   alone
# female 1      child False        NaN         NaN     0.666667
#               woman False   1.000000    1.000000     0.967742
#                     True    0.944444         NaN     1.000000
#        2      child False   1.000000         NaN     1.000000
#               woman False   1.000000         NaN     0.903226
#                     True    1.000000    1.000000     0.892857
#        3      child False   0.777778         NaN     0.312500
#                     True    1.000000    1.000000     0.500000
#               woman False   0.444444    0.625000     0.333333
#                     True    0.666667    0.750000     0.464286
# male   1      child False        NaN         NaN     1.000000
#               man   False   0.473684    0.000000     0.333333
#                     True    0.347826         NaN     0.326923
#        2      child False   1.000000         NaN     1.000000
# ...

# %%
sns.lmplot(x="survived",y="alone",data=df)

# %%
sns.lmplot(x="age",y="fare",hue="embarked",col="class",row="sex",data=df);

# %%
import matplotlib.pyplot as plt

# %%
sns.jointplot(x="age",y="alone",data=df,kind="reg")
